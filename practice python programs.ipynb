# %% [markdown]
# # to add two nos<a href="#to-add-two-nos" class="anchor-link">¶</a>
#
# In \[2\]:
#
#     a = 9
#     b = 10
#
#     value = print(a + b)
#     print(type(value))
#     type(a)
#
#     19
#     <class 'NoneType'>
#
# Out\[2\]:
#
#     int
#
# # to find sqrt of a number<a href="#to-find-sqrt-of-a-number" class="anchor-link">¶</a>
#
# In \[4\]:
#
#     b = 9
#     c = print (b ** 0.5)
#     type(c)
#     type(b)
#
#     3.0
#
# Out\[4\]:
#
#     int
#
# # to find the power of number<a href="#to-find-the-power-of--number" class="anchor-link">¶</a>
#
# In \[15\]:
#
#     a = 6
#     print ("value is:\n",a)
#     b = print(a ** 6)
#
#     value is:
#      6
#     46656
#
# # to find fibonacci of a number<a href="#to-find-fibonacci-of-a-number" class="anchor-link">¶</a>
#
# In \[74\]:
#
#     def Fibonacci(n):
#         if n<0:
#             print ("incorrect input")
#         elif n == 1:
#             return 0
#         elif n == 2:
#             return 1
#         else:
#             return Fibonacci(n-1) + Fibonacci(n-2)
#
#     print(Fibonacci(6))
#
#
#
#     5
#
# # to check a number is odd or even<a href="#to-check-a-number-is-odd-or-even" class="anchor-link">¶</a>
#
# In \[85\]:
#
#     a = 5
#     while (a<=50):
#         if(a % 2)==0:
#             print("number is even",a)
#         else:
#             print("number is odd",a)
#         a = a + 1
#
#     number is odd 5
#     number is even 6
#     number is odd 7
#     number is even 8
#     number is odd 9
#     number is even 10
#     number is odd 11
#     number is even 12
#     number is odd 13
#     number is even 14
#     number is odd 15
#     number is even 16
#     number is odd 17
#     number is even 18
#     number is odd 19
#     number is even 20
#     number is odd 21
#     number is even 22
#     number is odd 23
#     number is even 24
#     number is odd 25
#     number is even 26
#     number is odd 27
#     number is even 28
#     number is odd 29
#     number is even 30
#     number is odd 31
#     number is even 32
#     number is odd 33
#     number is even 34
#     number is odd 35
#     number is even 36
#     number is odd 37
#     number is even 38
#     number is odd 39
#     number is even 40
#     number is odd 41
#     number is even 42
#     number is odd 43
#     number is even 44
#     number is odd 45
#     number is even 46
#     number is odd 47
#     number is even 48
#     number is odd 49
#     number is even 50
#
# # to find the factorial of a given no<a href="#to-find-the-factorial-of-a-given-no" class="anchor-link">¶</a>
#
# In \[18\]:
#
#     def factorial(n):
#         if(n < 5):
#             return 1
#         else:
#             return n*factorial(n-1)
#
#     factorial(9)
#
# Out\[18\]:
#
#     15120
#
# # to find a prime no<a href="#to-find-a-prime-no" class="anchor-link">¶</a>
#
# In \[8\]:
#
#     n = 500
#     for i in range(2,n):
#         if n%i ==0:
#             print("numbr is prime no",i)
#         else:
#             print("number is not a prime number")
#
#
#     numbr is prime no 2
#     number is not a prime number
#     numbr is prime no 4
#     numbr is prime no 5
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     numbr is prime no 10
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     numbr is prime no 20
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     numbr is prime no 25
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     numbr is prime no 50
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     numbr is prime no 100
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     numbr is prime no 125
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     numbr is prime no 250
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#     number is not a prime number
#
# In \[38\]:
#
#     a = 100
#     for i in range (2,a):
#         if (i% 2!= 0):
#             print("odd number",i)
#         else :
#             print("even number",i)
#
#     even number 2
#     odd number 3
#     even number 4
#     odd number 5
#     even number 6
#     odd number 7
#     even number 8
#     odd number 9
#     even number 10
#     odd number 11
#     even number 12
#     odd number 13
#     even number 14
#     odd number 15
#     even number 16
#     odd number 17
#     even number 18
#     odd number 19
#     even number 20
#     odd number 21
#     even number 22
#     odd number 23
#     even number 24
#     odd number 25
#     even number 26
#     odd number 27
#     even number 28
#     odd number 29
#     even number 30
#     odd number 31
#     even number 32
#     odd number 33
#     even number 34
#     odd number 35
#     even number 36
#     odd number 37
#     even number 38
#     odd number 39
#     even number 40
#     odd number 41
#     even number 42
#     odd number 43
#     even number 44
#     odd number 45
#     even number 46
#     odd number 47
#     even number 48
#     odd number 49
#     even number 50
#     odd number 51
#     even number 52
#     odd number 53
#     even number 54
#     odd number 55
#     even number 56
#     odd number 57
#     even number 58
#     odd number 59
#     even number 60
#     odd number 61
#     even number 62
#     odd number 63
#     even number 64
#     odd number 65
#     even number 66
#     odd number 67
#     even number 68
#     odd number 69
#     even number 70
#     odd number 71
#     even number 72
#     odd number 73
#     even number 74
#     odd number 75
#     even number 76
#     odd number 77
#     even number 78
#     odd number 79
#     even number 80
#     odd number 81
#     even number 82
#     odd number 83
#     even number 84
#     odd number 85
#     even number 86
#     odd number 87
#     even number 88
#     odd number 89
#     even number 90
#     odd number 91
#     even number 92
#     odd number 93
#     even number 94
#     odd number 95
#     even number 96
#     odd number 97
#     even number 98
#     odd number 99
#
# # odd and even using while loop<a href="#odd-and-even-using-while-loop" class="anchor-link">¶</a>
#
# In \[45\]:
#
#     i=10
#     while(i<=50):
#         if(i%2==0):
#             print("even no",i)
#         else:
#             print("odd no",i)
#         i=i+1
#
#     even no 10
#     odd no 11
#     even no 12
#     odd no 13
#     even no 14
#     odd no 15
#     even no 16
#     odd no 17
#     even no 18
#     odd no 19
#     even no 20
#     odd no 21
#     even no 22
#     odd no 23
#     even no 24
#     odd no 25
#     even no 26
#     odd no 27
#     even no 28
#     odd no 29
#     even no 30
#     odd no 31
#     even no 32
#     odd no 33
#     even no 34
#     odd no 35
#     even no 36
#     odd no 37
#     even no 38
#     odd no 39
#     even no 40
#     odd no 41
#     even no 42
#     odd no 43
#     even no 44
#     odd no 45
#     even no 46
#     odd no 47
#     even no 48
#     odd no 49
#     even no 50
#
# # average of numbers in given list<a href="#average-of-numbers-in-given-list" class="anchor-link">¶</a>
#
# In \[47\]:
#
#     a = [10,20,30,40,50]
#     print("average of given no is\n")
#     b = a[0]+a[1]+a[2]+a[3]+a[4]/2
#     print(b)
#
#     average of given no is
#
#     125.0
#
# # to find the largest of 2 numbers<a href="#to-find-the-largest-of-2-numbers" class="anchor-link">¶</a>
#
# In \[10\]:
#
#     a = 9
#     b = 19
#     if a<=b:
#         print("it is a largest no")
#     else:
#         print("it is a smallest no")
#
#     it is a largest no
#
# # to find the largest of 2 nos.<a href="#to-find-the-largest-of-2-nos." class="anchor-link">¶</a>
#
# In \[15\]:
#
#     a = input("enter 1st  number")
#     b = input("enter 2nd number")
#     if (a>b):
#         print("it is a largest no.")
#     elif (a<b):
#         print("it is a smallest number")
#     else:
#         print("both values are equal")
#
#     enter 1st  number80
#     enter 2nd number80
#     both values are equal
#
# # largest of 3 numbers<a href="#largest-of-3-numbers" class="anchor-link">¶</a>
#
# In \[22\]:
#
#     a = input("enter 1st no.")
#     b = input("enter 2nd number")
#     c = input("enter 3rd number")
#     if(a>b and a>c):
#         print("a is greater than b and c".format(a,b,c))
#     elif(b>a and b>c):
#         print("b is greater than a and c".format(b,a,c))
#     elif(c>a and c>b):
#         print("c is greater than a and b".format(c,a,b))
#     else:
#         print("default all values are equal or only two values are equal")
#
#     enter 1st no.32
#     enter 2nd number45
#     enter 3rd number98
#     c is greater than a and b
#
# In \[14\]:
#
#     from array import *
#     a = array('i',[5,6,7,8,9])
#     for i in a:
#         print(i)
#
#     5
#     6
#     7
#     8
#     9
#
# # python program to find largest no in list<a href="#python-program-to-find-largest-no-in-list" class="anchor-link">¶</a>
#
# In \[37\]:
#
#     def max1(list):
#         max =list[0]
#         for a in list:
#             if a > max:
#                 max=a
#         return max
#
#     print(max1([1,2,9,3]))
#
#     9
#
# In \[41\]:
#
#     def smallest_no(list):
#         small = list[0]
#         for a in list:
#             if(a<small):
#                 small = a
#         return small
#     print(smallest_no([5,8,3,2]))
#
#     2
#
# # getting user input<a href="#getting-user-input" class="anchor-link">¶</a>
#
# In \[7\]:
#
#     def num(a):
#         print("value is:\n",a)
#
#
#     num(9)
#     print("enter the number:")
#
#     value is:
#      9
#     enter the number:
#
# In \[14\]:
#
#     a = input("enter the number:")
#     print(a)
#
#     enter the number:90
#     90
#
# # python program to add two binary nos<a href="#python-program-to-add-two-binary--nos" class="anchor-link">¶</a>
#
# In \[20\]:
#
#     a = '00001'
#     b = '10001'
#     sum = bin(int(a,2) + int(b,2))
#     print(sum)
#
#     0b10010
#
# # convert decimal to binary no<a href="#convert-decimal-to-binary-no" class="anchor-link">¶</a>
#
# In \[24\]:
#
#     a = int(input("enter a given no:\n"))
#     b = print("equivalent binary no:\n",bin(a))
#
#     enter a given no:
#     56
#     equivalent binary no:
#      0b111000
#
# # to check whether a no is positive or negative or 0<a href="#to-check-whether-a-no-is-positive-or-negative-or-0" class="anchor-link">¶</a>
#
# In \[7\]:
#
#     a = int(input("enter the no:\n"))
#     if(a > 0):
#         print("it is positive no:\n")
#     elif(a == 0):
#         print("equal to 0")
#     else:
#         print("it is negative no")
#
#
#     enter the no:
#     65
#     it is positive no:
#
# # program to find square root<a href="#program-to-find-square-root" class="anchor-link">¶</a>
#
# In \[10\]:
#
#     def sqrt(a):
#         print("square root of a number is:\n")
#         num = a ** 0.5
#         print(num)
#     sqrt(4)
#
#
#     square root of a number is:
#
#     2.0
#
# # program to display the multiplication of table<a href="#program-to-display-the-multiplication-of-table" class="anchor-link">¶</a>
#
# In \[11\]:
#
#     a = int(input("enter the no:\n"))
#     for i in range(1,12):
#         print(num,'x',i, '=',num*i)
#
#     enter the no:
#     10
#     11 x 1 = 11
#     11 x 2 = 22
#     11 x 3 = 33
#     11 x 4 = 44
#     11 x 5 = 55
#     11 x 6 = 66
#     11 x 7 = 77
#     11 x 8 = 88
#     11 x 9 = 99
#     11 x 10 = 110
#     11 x 11 = 121
#
# # program to find out add,sub,mul,divi of nos<a href="#program-to-find-out-add,sub,mul,divi-of-nos" class="anchor-link">¶</a>
#
# In \[3\]:
#
#     def add(x,y):
#         return x + y
#
#     def sub(x,y):
#         return x - y
#
#     def multiply(x,y):
#         return x * y
#
#     def divide(x,y):
#         return x/y
#
#     "select operation:"
#     print("addition \n",add(2,3))
#     print("subtract \n",sub(3,2))
#     print("multiply \n",multiply(4,5))
#     print("divide \n",divide(6,3))
#
#     addition
#      5
#     subtract
#      1
#     multiply
#      20
#     divide
#      2.0
#
# # program to find calculator<a href="#program-to-find-calculator" class="anchor-link">¶</a>
#
# In \[13\]:
#
#     def add(a,b):
#         return a + b
#     def sub(a,b):
#         return a - b
#     def multiply(a,b):
#         return a * b
#     def divide(a,b):
#         return a/b
#
#     "select operation:"
#     print("1.add")
#     print("2.subtract")
#     print("3.multiply")
#     print("4.divide")
#
#     choice = input("enter ur choice(1/2/3/4):")
#
#     num1 = int(input("enter 1st no:"))
#     num2 = int(input("enter 2nd no:"))
#
#     if choice == "1":
#         print(num1,"+",num2,"=",add(num1,num2))
#     elif choice == "2":
#         print(num1,"-",num2,"=",sub(num1,num2))
#     elif choice == "3":
#         print(num1,"*",num2,"=",multiply(num1,num2))
#     elif choice == "4":
#         print(num1,"/",num2,"=",divide(num1,num2))
#     else:
#         print("invalid input")
#
#     1.add
#     2.subtract
#     3.multiply
#     4.divide
#     enter ur choice(1/2/3/4):1
#     enter 1st no:12
#     enter 2nd no:12
#     12 + 12 = 24
#
# In \[ \]:
